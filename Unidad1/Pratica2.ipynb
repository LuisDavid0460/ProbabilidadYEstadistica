# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisDavid0460/ProbabilidadYEstadistica/blob/main/Unidad1/Pratica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadistica**
#
# ## Unidad 1
#
# ### Practica 2. **Maximo, Minimo, Rango y dispersion de datos**
#
# ### Facilitador *Dr. Jose Gabriel Rodriguez Rivas*
#
# ### Alumno: *Hernandez Gomez Luis David*

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)

print(fabrica1)
# Out:
# [78.86, 95.78, 99.4, 95.0, 56.3, 58.42, 73.02, 77.46, 57.76, 96.13, 95.9, 76.74, 71.67, 96.97, 89.28, 85.45, 72.74, 85.58, 67.04, 89.8, 83.93, 54.71, 57.33, 53.06, 50.11, 63.82, 89.4, 59.28, 79.04, 79.53, 84.51, 76.71, 81.84, 88.66, 51.28, 76.19, 83.95, 96.75, 72.06, 70.41, 55.52, 62.88, 63.39, 50.27, 78.45, 77.73, 87.57, 56.59, 85.09, 93.32, 58.15, 61.24, 50.76, 57.21, 65.59, 66.55, 84.26, 57.75, 75.42, 99.61, 60.58, 85.35, 83.47, 86.16, 92.52, 56.38, 86.07, 66.05, 53.03, 71.14, 84.38, 74.85, 78.67, 83.03, 60.66, 50.76, 64.06, 87.41, 88.93, 92.08, 79.54, 66.73, 89.27, 56.42, 90.52, 79.1, 50.44, 61.21, 90.68, 63.9, 87.68, 75.93, 59.86, 66.88, 99.55, 97.71, 57.05, 69.85, 89.72, 65.66]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(70, 100), 2)
  fabrica2.append(numero_aleatorio)

print(fabrica2)
# Out:
# [98.76, 72.66, 93.12, 75.21, 92.26, 70.39, 79.08, 93.91, 89.58, 74.21, 92.18, 89.98, 71.76, 80.58, 75.61, 78.42, 78.32, 72.55, 97.79, 74.99, 79.46, 70.72, 86.29, 87.65, 82.78, 70.04, 82.45, 86.79, 89.82, 84.57, 94.32, 84.56, 87.38, 90.0, 95.97, 75.43, 81.03, 72.16, 96.42, 79.5, 81.41, 91.67, 88.73, 99.83, 91.34, 74.95, 90.73, 94.83, 77.94, 71.6, 81.42, 75.31, 82.65, 78.9, 86.09, 72.85, 97.68, 88.55, 80.12, 93.09, 87.79, 83.51, 85.35, 74.18, 87.85, 82.96, 75.85, 73.95, 80.79, 74.69, 85.47, 75.32, 94.85, 98.94, 85.59, 75.08, 89.69, 74.72, 76.3, 92.94, 71.98, 88.89, 96.42, 70.1, 91.88, 91.07, 73.14, 81.52, 95.7, 99.27, 87.1, 77.7, 91.71, 71.57, 73.53, 88.05, 88.65, 71.14, 86.13, 74.64]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1= mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("Estadistica descriptiva de la Fabrica 1 \n " "Media = ", media1,
      "\n Mediana =", mediana1, "\n Moda =", moda1, "\n Maximo = ", maximo1,
    "\n Minimo =", minimo1, "\n Rango =", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media =  74.625
#  Mediana = 76.44999999999999
#  Moda = 50.76
#  Maximo =  99.61
#  Minimo = 50.11
#  Rango = 49.5
# 14.588471891230148

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2= mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("Estadistica descriptiva de la Fabrica 2 \n " "Media = ", media2,
      "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo = ", maximo2,
    "\n Minimo =", minimo2, "\n Rango =", rango2)
print(desviacion_estandar_fabrica2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#  Media =  83.544
#  Mediana = 83.235
#  Moda = 96.42
#  Maximo =  99.83
#  Minimo = 70.04
#  Rango = 29.789999999999992
# 8.559727527996166

# %%
plt.figure(figsize = (8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor="black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color="y", linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frencuencia')
plt.title('Produccion diaria de la fabrica 1')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,6))
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor="black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color="y", linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frencuencia')
plt.title('Produccion diaria de la fabrica 2')
plt.legend()
plt.show()

# %%
# Diagrama de densidad

import seaborn as sns
sns.histplot( x = fabrica1, kde=True, kde_kws = {'bw_adjust': 0.5}, bins=10)

<Axes: ylabel='Count'>
# Out:
#   File "/tmp/ipykernel_1266/1602388015.py", line 6
#     <Axes: ylabel='Count'>
#     ^
# SyntaxError: invalid syntax
