# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisDavid0460/ProbabilidadYEstadistica/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadistica**
#
# ## **Unidad 1**
#
# ### Practica 3. **Tabla de frecuencias y regla de Sturges.**
#
# ### Facilitador *Dr. Jose Gabriel Rivas Rodriguez*
#
# ### Alumno *Hernandez Gomez Luis David*

# %%
import random
edades = []

for i in range(100):
  numero_aleatorio = random.randint(18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [41, 18, 32, 25, 57, 61, 46, 64, 70, 22, 41, 51, 65, 34, 37, 46, 47, 68, 37, 18, 57, 47, 37, 22, 51, 45, 31, 60, 24, 69, 69, 51, 39, 62, 47, 62, 22, 46, 56, 49, 36, 65, 20, 63, 64, 63, 54, 37, 65, 67, 47, 26, 42, 56, 35, 23, 58, 48, 65, 53, 62, 52, 44, 19, 38, 44, 21, 45, 52, 59, 43, 46, 30, 28, 33, 39, 39, 46, 45, 32, 20, 19, 37, 18, 60, 38, 25, 20, 58, 42, 28, 31, 67, 31, 25, 65, 53, 34, 36, 60]

# %%
import pandas as pd

df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    41
# 1    18
# 2    32
# 3    25
# 4    57

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

print("Tabla de Distribucion de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribucion de Frecuencias:
#     Edad  Frecuencia
# 6     18           3
# 31    19           2
# 9     20           3
# 42    21           1
# 7     22           3
# 40    23           1
# 38    24           1
# 5     25           3
# 34    26           1
# 16    28           2
# 45    30           1
# 13    31           3
# 19    32           2
# 46    33           1
# 18    34           2
# 41    35           1
# 25    36           2
# 2     37           5
# 15    38           2
# 10    39           3
# 20    41           2
# 30    42           2
# 44    43           1
# 26    44           2
# 12    45           3
# 0     46           5
# 3     47           4
# 39    48           1
# 37    49           1
# 4     51           3
# 28    52           2
# 27    53           2
# 36    54           1
# 21    56           2
# 14    57           2
# 29    58           2
# 43    59           1
# 8     60           3
# 32    61           1
# 11    62           3
# 24    63           2
# 17    64           2
# 1     65           5
# 23    67           2
# 35    68           1
# 22    69           2
# 33    70           1

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 6     18           3           0.03
# 31    19           2           0.02
# 9     20           3           0.03
# 42    21           1           0.01
# 7     22           3           0.03
# 40    23           1           0.01
# 38    24           1           0.01
# 5     25           3           0.03
# 34    26           1           0.01
# 16    28           2           0.02
# 45    30           1           0.01
# 13    31           3           0.03
# 19    32           2           0.02
# 46    33           1           0.01
# 18    34           2           0.02
# 41    35           1           0.01
# 25    36           2           0.02
# 2     37           5           0.05
# 15    38           2           0.02
# 10    39           3           0.03
# 20    41           2           0.02
# 30    42           2           0.02
# 44    43           1           0.01
# 26    44           2           0.02
# 12    45           3           0.03
# 0     46           5           0.05
# 3     47           4           0.04
# 39    48           1           0.01
# 37    49           1           0.01
# 4     51           3           0.03
# 28    52           2           0.02
# 27    53           2           0.02
# 36    54           1           0.01
# 21    56           2           0.02
# 14    57           2           0.02
# 29    58           2           0.02
# 43    59           1           0.01
# 8     60           3           0.03
# 32    61           1           0.01
# 11    62           3           0.03
# 24    63           2           0.02
# 17    64           2           0.02
# 1     65           5           0.05
# 23    67           2           0.02
# 35    68           1           0.01
# 22    69           2           0.02
# 33    70           1           0.01

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()

# %%
import math

# %%
print(edades)
# Out:
# [41, 18, 32, 25, 57, 61, 46, 64, 70, 22, 41, 51, 65, 34, 37, 46, 47, 68, 37, 18, 57, 47, 37, 22, 51, 45, 31, 60, 24, 69, 69, 51, 39, 62, 47, 62, 22, 46, 56, 49, 36, 65, 20, 63, 64, 63, 54, 37, 65, 67, 47, 26, 42, 56, 35, 23, 58, 48, 65, 53, 62, 52, 44, 19, 38, 44, 21, 45, 52, 59, 43, 46, 30, 28, 33, 39, 39, 46, 45, 32, 20, 19, 37, 18, 60, 38, 25, 20, 58, 42, 28, 31, 67, 31, 25, 65, 53, 34, 36, 60]

# %%
df = pd.DataFrame({'Edad' : edades})

# %%
n = len(edades)
K = int(1+math.log2(n))
print("Valor de n = ", n, "\nNumero de intervalos ? ", K)
# Out:
# Valor de n =  100
# Numero de intervalos ?  7

# %%
tabla_frecuencia = pd.cut( df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (40.286, 47.714]    19
# 1  (17.947, 25.429]    17
# 2  (32.857, 40.286]    16
# 3    (62.571, 70.0]    15
# 4  (55.143, 62.571]    14
# 5  (47.714, 55.143]    10
# 6  (25.429, 32.857]     9

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 1  (17.947, 25.429]    17
# 6  (25.429, 32.857]     9
# 2  (32.857, 40.286]    16
# 0  (40.286, 47.714]    19
# 5  (47.714, 55.143]    10
# 4  (55.143, 62.571]    14
# 3    (62.571, 70.0]    15

# %%
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 1  (17.947, 25.429]    17      0.17       17.0       17         0.17
# 6  (25.429, 32.857]     9      0.09        9.0       26         0.26
# 2  (32.857, 40.286]    16      0.16       16.0       42         0.42
# 0  (40.286, 47.714]    19      0.19       19.0       61         0.61
# 5  (47.714, 55.143]    10      0.10       10.0       71         0.71
# 4  (55.143, 62.571]    14      0.14       14.0       85         0.85
# 3    (62.571, 70.0]    15      0.15       15.0      100         1.00
#
#    Frec Porc Ac
# 1          17.0
# 6          26.0
# 2          42.0
# 0          61.0
# 5          71.0
# 4          85.0
# 3         100.0

# %%
import matplotlib.pyplot as plt
from statistics import *

# %%
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib')

# %%
plt.hist(df['Edad'], bins=K, alpha=0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
